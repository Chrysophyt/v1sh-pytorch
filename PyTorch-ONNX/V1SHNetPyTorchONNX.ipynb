# %%
import numpy as np 
import cv2 as cv  

import torch                        
import torch.nn.functional as F
import torch.nn as nn

# %% [markdown]
# ## Create Gabor To Hypercolumns ONNX Model

# %%
def get_gabor_weights(kernel_size, K_dim):
    """
    return CNN 2D Weights that operate a grayscale image to K-dim hypercolumns
    weights dimension : [K (hypercolumns), 1 (grayscale), kernel_size, kernel_size]
                         Final dimension , Previous dim
    
    """
    sigma = np.sqrt(kernel_size) # Standard deviation of the Gaussian envelope
    thetas = [(np.pi*k/K_dim) - (np.pi/2) for k in range(K_dim)]# The orientation of the normal to the parallel stripes of Gabor function
    lambd = kernel_size/2# Wavelength of the sinusoidal component
    gamma = 0.7# The spatial aspect ratio and specifies the ellipticity of the support of Gabor
    gabor_kernel_K = []

    for theta in thetas:
        gabor_kernel_K.append(cv.getGaborKernel((kernel_size, kernel_size), sigma, theta, lambd, gamma))

    return torch.from_numpy(np.asarray(gabor_kernel_K).astype('float32')).unsqueeze(1)

# %%
def get_phi_weights(K=12):
    """
    return phi() function as vectorized CNN 2D Weights
    weights dimension : [Hypercolumn dim , Hypercolumn dim, 1, 1]
    """
    # Range check func
    def range_check(k):
        if k < -np.pi/2:
            return k + np.pi
        if k > np.pi/2:
            return k - np.pi
        return k

    # set const
    orientations_K = [(np.pi*k/K) - (np.pi/2) for k in range(K)]
    pi_8 = np.pi/8

    delta_w = []
    for k in range(K):          # k from theta
        delta_w1 = []
        for k_r in range(K):    # k from raw/ beta
            delta = range_check(orientations_K[torch.tensor(k)] - orientations_K[torch.tensor(k_r)])
            delta_w1.append(np.exp(-np.abs(delta)/pi_8))
        delta_w.append(delta_w1)

    return torch.from_numpy(np.asarray(delta_w).astype('float32')).unsqueeze(2).unsqueeze(3)

# %%
class GaborToHypercolumns(nn.Module):
    def __init__(self, kernel_size=21, K=12, c_mul = 3.01, device='cpu'):
        super().__init__()
        self.kernel_size = kernel_size
        self.gabor_weights = get_gabor_weights(kernel_size, K)
        self.phi_weights = get_phi_weights(K)
        self.c_mul = c_mul


    def forward(self, input_grayscale):
        """
        input_grayscale : [300, 500]
        output : [56, 96]
        """
        input_grayscale = input_grayscale.unsqueeze(0).unsqueeze(0) #[H, W] -> [1,1,H,W]
        out = F.conv2d(input_grayscale, self.gabor_weights, stride=5)

        # Normalize gabor result by removing negative values and normalizing [0, out.max()] -> [0, 1]
        out = torch.nn.functional.relu(out)
        out = out / out.max()

        # Phi
        out = F.conv2d(out, self.phi_weights, stride=1)
        out = out * self.c_mul

        return out.squeeze(0)

# %%
GTHModel = GaborToHypercolumns()

# %%
dummy_input = torch.zeros([300, 500])

torch.onnx.export(GTHModel, 
                  dummy_input, 
                  "GTHModel.onnx", 
                  verbose=True, 
                  export_params=True,
                  input_names=['grayscale'], 
                  output_names=['hypercolumns'],
                  opset_version=11)
# Out:
# graph(%grayscale : Float(300, 500, strides=[500, 1], requires_grad=0, device=cpu)):
#   %1 : Float(1, 300, 500, strides=[150000, 500, 1], requires_grad=0, device=cpu) = onnx::Unsqueeze[axes=[0]](%grayscale) # <ipython-input-11-15bb3ef5337f>:15:0
#   %2 : Float(1, 1, 300, 500, strides=[150000, 150000, 500, 1], requires_grad=0, device=cpu) = onnx::Unsqueeze[axes=[0]](%1) # <ipython-input-11-15bb3ef5337f>:15:0
#   %3 : Float(12, 1, 21, 21, strides=[441, 441, 21, 1], requires_grad=0, device=cpu) = onnx::Constant[value=<Tensor>]() # <ipython-input-11-15bb3ef5337f>:16:0
#   %4 : Float(1, 12, 56, 96, strides=[64512, 5376, 96, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[21, 21], pads=[0, 0, 0, 0], strides=[5, 5]](%2, %3) # <ipython-input-11-15bb3ef5337f>:16:0
#   %5 : Float(1, 12, 56, 96, strides=[64512, 5376, 96, 1], requires_grad=0, device=cpu) = onnx::Relu(%4) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:1298:0
#   %6 : Float(requires_grad=0, device=cpu) = onnx::ReduceMax[keepdims=0](%5) # <ipython-input-11-15bb3ef5337f>:20:0
#   %7 : Float(1, 12, 56, 96, strides=[64512, 5376, 96, 1], requires_grad=0, device=cpu) = onnx::Div(%5, %6) # <ipython-input-11-15bb3ef5337f>:20:0
#   %8 : Float(12, 12, 1, 1, strides=[12, 1, 1, 1], requires_grad=0, device=cpu) = onnx::Constant[value=<Tensor>]() # <ipython-input-11-15bb3ef5337f>:23:0
#   %9 : Float(1, 12, 56, 96, strides=[64512, 5376, 96, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%7, %8) # <ipython-input-11-15bb3ef5337f>:23:0
#   %10 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={3.01}]()
#   %11 : Float(1, 12, 56, 96, strides=[64512, 5376, 96, 1], requires_grad=0, device=cpu) = onnx::Mul(%9, %10)
#   %hypercolumns : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Squeeze[axes=[0]](%11) # <ipython-input-11-15bb3ef5337f>:25:0
#   return (%hypercolumns)

# %% [markdown]
# ## Create V1SH init

# %%
def pGainFunction(input_raw, T_x = 1):
    input = input_raw.clone()
    
    case1 = input < T_x
    input[case1] = 0
    
    case2 = torch.logical_and((T_x <= input), (input <= T_x + 1))
    input[case2] = input[case2] - T_x
    
    case3 = input > T_x + 1
    input[case3] = 1

    return input

def mGainFunction(input_raw, L_y=1.2, g_1=0.21, g_2=2.5):
    input = input_raw.clone()

    case1 = input < 0
    input[case1] = 0

    case2 = torch.logical_and((input >= 0), (input <= L_y))
    input[case2] =  input[case2] * g_1

    case3 = (input >= L_y)
    input[case3] =  g_1*L_y + g_2*(input[case3]-L_y)

    return input

# %%
class V1SHNetInit(nn.Module):
    def __init__(self, h, w, K=12, device='cpu'):
        super().__init__()
        # Params
        self.device = device
        self.K = K
        self.h = h
        self.w = w

        self.selfmp = -1.0

        self.fw1 = 0.8
        self.fw2 = 0.7
        
        self.backIm = 1.0
        self.backIp = 0.85
        self.decay = 1.0


        self.init_x = torch.tensor(self.backIm/ self.decay, device=device)
        self.init_x = self.selfmp*self.init_x*(1.0+self.fw1*2.0 + self.fw2*2.0)
        self.init_x = (self.backIp + self.init_x)/self.decay

        

    def forward(self, blank=0):
        Sp = torch.full([self.K, self.h, self.w], self.init_x, device=self.device)
        Sm = torch.full([self.K, self.h, self.w], self.backIm/ self.decay, device=self.device)
        return Sp, Sm

# %%
V1SHNetInitModel = V1SHNetInit(56, 96)

# %%
torch.onnx.export(V1SHNetInitModel, 
                  0,
                  f="V1SHNetInitModel.onnx", 
                  verbose=True, 
                  export_params=True,
                  input_names=['dummy'], 
                  output_names=['ExcitatoryCell', 'InhibitoryCell'],
                  opset_version=11)
# Out:
# graph():
#   %ExcitatoryCell : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Constant[value=<Tensor>]()
#   %InhibitoryCell : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Constant[value=<Tensor>]()
#   return (%ExcitatoryCell, %InhibitoryCell)

# %% [markdown]
# ## Create V1 Saliency Hypothesis ONNX Model

# %%
def synaptic_connection_J(d, theta1, theta2, angle, curvature):
    def cppdistance(distance):
        return np.exp(-np.power(distance, 2.0)/90.0)/2.7

    if (angle < np.pi/2.69 or 
    (angle < np.pi/1.10000 and np.abs(theta1) < np.pi/5.9 and np.abs(theta2) < np.pi/5.9)):
        return 0.126*np.exp(-(curvature)**2-2*(curvature)**7-cppdistance(d))
    else:
        return 0

def inhibitory_connection_W(d, theta1, theta2, angle, curvature, delta_K, selfpm=1.0):
    def cpmdistance(distance):
        #if(distance<9.999): 
        #    g = np.exp(-distance/30.0)/1.25
        if(distance<9.999): 
            return 1.0/1.75
        return 0.0

    if (angle >= np.pi/1.1) and (np.abs(theta1) > np.pi/11.999 and np.abs(theta2) > np.pi/11.999):
        x = delta_K
        if(x > np.pi/2.0): 
            x = np.pi-x

        if(x < np.pi/3.0):
            res = selfpm * np.exp(-np.power(x/(np.pi/4.0), 1.5)) * (1.0-1.00*np.exp(-0.4*np.power(curvature, 1.5)))
            res = res * cpmdistance(d/np.cos(angle/4.0))
            return res
    else:
        return 0
        
def get_exc_inh_weights(d=10, K=12, selfpm=1.0):
    """
    return the weight of both J, W
    """
    def get_connect_angle(P1, P2):
        x1, y1 = P1
        x2, y2 = P2

        x = (x2-x1)
        y = -(y2-y1) # y-axis flipped on computer array

        if(np.abs(x)>0):
            return np.arctan(y/x)
        elif(x==0):
            return np.pi/2
        return 0.0

    def range_check(k):
        if k < -np.pi/2:
            return k + np.pi
        if k > np.pi/2:
            return k - np.pi
        return k

    diameter = d*2 + 1
    kernel_J = np.zeros([K,K,diameter,diameter])
    kernel_W = np.zeros([K,K,diameter,diameter])

    orientations_K = [(np.pi*k/K) - (np.pi/2) for k in range(K)]

    mid_x = (diameter-1)/2
    mid_y = (diameter-1)/2

    for i in range(diameter):
        for j in range(diameter):

            # Get the euclidian distance
            distance = np.sqrt( (i-mid_x)**2 + (j-mid_y)**2 )
            if(0<distance<=d):
                for k1 in range(K):
                    for k2 in range(K):
                        connect_angle = get_connect_angle((mid_x, mid_y), (i, j))

                        theta1 = range_check(orientations_K[k1]-connect_angle)
                        theta2 = range_check(orientations_K[k2]-connect_angle)

                        if np.abs(theta1) > np.abs(theta2):
                            theta1, theta2 = theta2, theta1

                        angle = 2*np.abs(theta1) + 2*np.sin(np.abs(theta1+theta2))
                        curvature = angle/distance

                        delta_K = np.abs(orientations_K[k1] - orientations_K[k2])

                        kernel_J[k1][k2][j][i] = synaptic_connection_J(distance, theta1, theta2, angle, curvature)
                        kernel_W[k1][k2][j][i] = inhibitory_connection_W(distance, theta1, theta2, angle, curvature, delta_K, selfpm)

                        # (j,i) following image (h,w) convention
    return kernel_J, kernel_W # [K, K, diameter, diameter]

# %%
def I_norm_conv(cell_out, norm_width=2, norm_force=0.5, epsilon=0.01): 
    K, _, _ = cell_out.shape
    cell_out = cell_out.unsqueeze(0)  # [1, K1, h, w]

    weight = torch.from_numpy(np.ones([K, K, norm_width*2+1, norm_width*2+1]).astype('float32'))

    padded_input = F.pad(cell_out, 
                        (norm_width,norm_width,norm_width,norm_width), 
                        mode='circular') #[1,K,h+norm_width*2,w+norm_width*2]
    
    output = F.conv2d(padded_input, weight)   # [1, K1, h+pad, w+pad] -> [1, K2, h, w]

    # Do norm
    output = output / (4.0*norm_width*norm_width) # Element wise division
    output = 1.0 * output * output
    output = -1 * norm_force * epsilon * output

    # Apply norm
    out = F.relu(cell_out + output).squeeze(0)

    return out

# %%
class V1SHNetComputeMachine(nn.Module):
    def __init__(self, h, w, K=12, d=10, epsilon=0.05, device='cpu'):
        super().__init__()
        # Params
        self.device = device
        self.d = d
        self.K = K
        self.h = h
        self.w = w

        self.epsilon = epsilon
        self.selfpm = 1.0
        self.selfmp = -1.0
        self.selfpp = 0.8

        self.fw1 = 0.8
        self.fw2 = 0.7
        
        self.backIm = 1.0
        self.backIp = 0.85
        self.decay = 1.0

        self.angles = [(np.pi*k/K) - (np.pi/2) for k in range(K)]

        self.angle_weight = 0.0
        m = -K/12
        while(m<=K/12):
            self.angle_weight  += np.exp(-np.abs(m)/(K)*8.0)
            m+=1

        J_weights, W_weights = get_exc_inh_weights(self.d, self.K, self.selfpm)
        # Cpp, X, J, excitatory
        # Cpm, Y, W, inhibitory
        self.excitatory_weights = torch.from_numpy(J_weights.astype('float32')).to(device) / (self.angle_weight *1.45)
        self.inhibitory_weights = torch.from_numpy(W_weights.astype('float32')).to(device) / (self.angle_weight *2.00)
        

    def forward(self, I, Sp, Sm):
        # Get current output from gain function
        outSp = pGainFunction(Sp)
        outSm = mGainFunction(Sm)

        # Input Norm
        Sp = I_norm_conv(Sp, epsilon=self.epsilon)

        # p cell update
        pForce =  I - Sp*self.decay + self.selfpp*outSp
        pForce = pForce + self.backIp

        #   psi inhibition -> excitatory
        #     1
        pForce = pForce + self.selfmp*outSm
        #     0.8
        for k in range(self.K):
            pForce[k] = pForce[k] + self.selfmp*0.8*outSm[(k+1+self.K)%self.K]
            pForce[k] = pForce[k] + self.selfmp*0.8*outSm[(k-1+self.K)%self.K]
            pForce[k] = pForce[k] + self.selfmp*0.7*outSm[(k+2+self.K)%self.K]
            pForce[k] = pForce[k] + self.selfmp*0.7*outSm[(k-2+self.K)%self.K]

        #   excitatory connection
        outSpPad = F.pad(outSp.unsqueeze(0), #[1,12,H,W]
                        (self.d,self.d,self.d,self.d), 
                        mode='circular')
        pCon = F.conv2d(outSpPad, self.excitatory_weights).squeeze(0)
        
        pCh = pForce + pCon

        Sp = Sp + self.epsilon * pCh
        Sp = F.relu(Sp) #Remove negative value

        # m cell update
        mForce = self.selfpm*outSp - self.decay*Sm
        mForce = mForce + self.backIm

        outSpPad = F.pad(outSp.unsqueeze(0), #[1,12,H,W]
                        (self.d,self.d,self.d,self.d), 
                        mode='circular')

        mCon = F.conv2d(outSpPad, self.inhibitory_weights).squeeze(0)

        mCh = mForce + mCon

        Sm = Sm + self.epsilon * mCh
        Sm = F.relu(Sm) #Remove negative value

        outSp = pGainFunction(Sp)
        outSm = mGainFunction(Sm)

        return Sp, Sm, outSp, outSm, Sp.mean(), Sm.mean(), outSp.mean(), outSm.mean()

# %%
V1SHNetComputeMachineModel = V1SHNetComputeMachine(56, 96)

dummy_input1 = torch.zeros([12, 56, 96])
dummy_input2 = torch.zeros([12, 56, 96])
dummy_input3 = torch.zeros([12, 56, 96])

# %%
torch.onnx.export(V1SHNetComputeMachineModel, 
                  args=(dummy_input1, dummy_input2, dummy_input3),
                  f="V1SHComputeMachineModel.onnx", 
                  verbose=True, 
                  export_params=True,
                  do_constant_folding=True,
                  input_names=['ImageHypercolumnsInput', 'ExcitatoryCell', 'InhibitoryCell'], 
                  output_names=['ExcitatoryCell', 'InhibitoryCell', 'gExcitatoryCell', 'gInhibitoryCell', 'avgSp', 'avgSm', 'avgOutSp', 'avgOutSm'],
                  opset_version=11)
# Out:
# C:\Users\chrys\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:5: TracerWarning: torch.from_numpy results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   """
# graph(%ImageHypercolumnsInput : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu),
#       %ExcitatoryCell.1 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu),
#       %InhibitoryCell.1 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu),
#       %2915 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2916 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2917 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2918 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2919 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2920 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2921 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2922 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2923 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2924 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2925 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2926 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2927 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2928 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2929 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2930 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2931 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2932 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2933 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2934 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2935 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2936 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2937 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2938 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2940 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2941 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2943 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2944 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2946 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2947 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2949 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2950 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2952 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2953 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2955 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2956 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2958 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2959 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2961 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2962 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2964 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2965 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2967 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2968 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2970 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2971 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2973 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2974 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2976 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2977 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2979 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2980 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2982 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2983 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2985 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2986 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2988 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2989 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2991 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2992 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2994 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2995 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %2997 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %2998 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3000 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3001 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3003 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3004 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3006 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3007 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3009 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3010 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3012 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3013 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3015 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3016 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3018 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3019 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3021 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3022 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3024 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3025 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3027 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3028 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3030 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3031 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3033 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3034 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3036 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3037 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3039 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3040 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3042 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3043 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3045 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3046 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3048 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3049 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3051 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3052 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3054 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3055 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3057 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3058 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3060 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3061 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3063 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3064 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3066 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3067 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3069 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3070 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3072 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3073 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3075 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3076 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3078 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3079 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3081 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3082 : Long(1, 1, strides=[1, 1], requires_grad=0, device=cpu),
#       %3083 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3084 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3085 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3086 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3087 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3088 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3089 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3090 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3091 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3092 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3093 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3094 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3095 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3096 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3097 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3098 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3099 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3100 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3101 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3102 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3103 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3104 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3105 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3106 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3107 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3108 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3109 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3110 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3111 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3112 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3113 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3114 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3115 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3116 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3117 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3118 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3119 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3120 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3121 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3122 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3123 : Long(1, strides=[1], requires_grad=0, device=cpu),
#       %3124 : Long(1, strides=[1], requires_grad=0, device=cpu)):
#   %3 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %4 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Less(%ExcitatoryCell.1, %3) # <ipython-input-19-026558775876>:4:0
#   %5 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%4) # <ipython-input-19-026558775876>:5:0
#   %6 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%5)
#   %7 : Float(device=cpu) = onnx::Constant[value={0}]()
#   %8 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Where(%6, %7, %ExcitatoryCell.1) # <ipython-input-19-026558775876>:5:0
#   %9 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %10 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Less(%8, %9)
#   %11 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Not(%10) # <ipython-input-19-026558775876>:7:0
#   %12 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %13 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Greater(%8, %12)
#   %14 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Not(%13) # <ipython-input-19-026558775876>:7:0
#   %15 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%11)
#   %16 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%14)
#   %17 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::And(%15, %16)
#   %18 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%17) # <ipython-input-19-026558775876>:7:0
#   %19 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%18) # <ipython-input-19-026558775876>:8:0
#   %20 : Long(3, *, device=cpu) = onnx::NonZero(%19)
#   %21 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%20)
#   %22 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::GatherND(%8, %21) # <ipython-input-19-026558775876>:8:0
#   %23 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %24 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::Sub(%22, %23)
#   %25 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%19) # <ipython-input-19-026558775876>:8:0
#   %26 : Long(3, strides=[1], device=cpu) = onnx::Shape(%8)
#   %27 : Bool(12, 56, 96, device=cpu) = onnx::Expand(%25, %26)
#   %28 : Long(3, *, device=cpu) = onnx::NonZero(%27)
#   %29 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%28)
#   %30 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]()
#   %31 : Float(*, device=cpu) = onnx::Reshape(%24, %30)
#   %32 : Long(2, strides=[1], device=cpu) = onnx::Shape(%29)
#   %33 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %34 : Long(device=cpu) = onnx::Gather[axis=0](%32, %33)
#   %37 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%34)
#   %40 : Float(*, device=cpu) = onnx::Slice(%31, %2915, %37, %2916)
#   %41 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%8, %29, %40) # <ipython-input-19-026558775876>:8:0
#   %42 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %43 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Greater(%41, %42) # <ipython-input-19-026558775876>:10:0
#   %44 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%43) # <ipython-input-19-026558775876>:11:0
#   %45 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%44)
#   %46 : Float(device=cpu) = onnx::Constant[value={1}]()
#   %47 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Where(%45, %46, %41) # <ipython-input-19-026558775876>:11:0
#   %48 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %49 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Less(%InhibitoryCell.1, %48) # <ipython-input-19-026558775876>:18:0
#   %50 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%49) # <ipython-input-19-026558775876>:19:0
#   %51 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%50)
#   %52 : Float(device=cpu) = onnx::Constant[value={0}]()
#   %53 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Where(%51, %52, %InhibitoryCell.1) # <ipython-input-19-026558775876>:19:0
#   %54 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %55 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Less(%53, %54)
#   %56 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Not(%55) # <ipython-input-19-026558775876>:21:0
#   %57 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1.2}]()
#   %58 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Greater(%53, %57)
#   %59 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Not(%58) # <ipython-input-19-026558775876>:21:0
#   %60 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%56)
#   %61 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%59)
#   %62 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::And(%60, %61)
#   %63 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%62) # <ipython-input-19-026558775876>:21:0
#   %64 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%63) # <ipython-input-19-026558775876>:22:0
#   %65 : Long(3, *, device=cpu) = onnx::NonZero(%64)
#   %66 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%65)
#   %67 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::GatherND(%53, %66) # <ipython-input-19-026558775876>:22:0
#   %68 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.21}]()
#   %69 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::Mul(%67, %68)
#   %70 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%64) # <ipython-input-19-026558775876>:22:0
#   %71 : Long(3, strides=[1], device=cpu) = onnx::Shape(%53)
#   %72 : Bool(12, 56, 96, device=cpu) = onnx::Expand(%70, %71)
#   %73 : Long(3, *, device=cpu) = onnx::NonZero(%72)
#   %74 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%73)
#   %75 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]()
#   %76 : Float(*, device=cpu) = onnx::Reshape(%69, %75)
#   %77 : Long(2, strides=[1], device=cpu) = onnx::Shape(%74)
#   %78 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %79 : Long(device=cpu) = onnx::Gather[axis=0](%77, %78)
#   %82 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%79)
#   %85 : Float(*, device=cpu) = onnx::Slice(%76, %2917, %82, %2918)
#   %86 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%53, %74, %85) # <ipython-input-19-026558775876>:22:0
#   %87 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1.2}]()
#   %88 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Less(%86, %87)
#   %89 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Not(%88) # <ipython-input-19-026558775876>:24:0
#   %90 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%89) # <ipython-input-19-026558775876>:25:0
#   %91 : Long(3, *, device=cpu) = onnx::NonZero(%90)
#   %92 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%91)
#   %93 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::GatherND(%86, %92) # <ipython-input-19-026558775876>:25:0
#   %94 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1.2}]()
#   %95 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::Sub(%93, %94)
#   %96 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2.5}]()
#   %97 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::Mul(%95, %96)
#   %98 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.252}]()
#   %99 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::Add(%97, %98)
#   %100 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%90) # <ipython-input-19-026558775876>:25:0
#   %101 : Long(3, strides=[1], device=cpu) = onnx::Shape(%86)
#   %102 : Bool(12, 56, 96, device=cpu) = onnx::Expand(%100, %101)
#   %103 : Long(3, *, device=cpu) = onnx::NonZero(%102)
#   %104 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%103)
#   %105 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]()
#   %106 : Float(*, device=cpu) = onnx::Reshape(%99, %105)
#   %107 : Long(2, strides=[1], device=cpu) = onnx::Shape(%104)
#   %108 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %109 : Long(device=cpu) = onnx::Gather[axis=0](%107, %108)
#   %112 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%109)
#   %115 : Float(*, device=cpu) = onnx::Slice(%106, %2919, %112, %2920)
#   %116 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%86, %104, %115) # <ipython-input-19-026558775876>:25:0
#   %117 : Float(1, 12, 56, 96, strides=[64512, 5376, 96, 1], requires_grad=0, device=cpu) = onnx::Unsqueeze[axes=[0]](%ExcitatoryCell.1) # <ipython-input-27-0f81e3494ea6>:3:0
#   %118 : Long(4, strides=[1], device=cpu) = onnx::Shape(%117)
#   %119 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %120 : Long(device=cpu) = onnx::Gather[axis=0](%118, %119) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4560:0
#   %121 : Long(4, strides=[1], device=cpu) = onnx::Shape(%117)
#   %122 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %123 : Long(device=cpu) = onnx::Gather[axis=0](%121, %122) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4560:0
#   %124 : Long(4, strides=[1], device=cpu) = onnx::Shape(%117)
#   %125 : Long(device=cpu) = onnx::Constant[value={2}]()
#   %126 : Long(device=cpu) = onnx::Gather[axis=0](%124, %125) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4560:0
#   %127 : Long(4, strides=[1], device=cpu) = onnx::Shape(%117)
#   %128 : Long(device=cpu) = onnx::Constant[value={3}]()
#   %129 : Long(device=cpu) = onnx::Gather[axis=0](%127, %128) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4560:0
#   %130 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %131 : Long(requires_grad=0, device=cpu) = onnx::Add(%126, %130)
#   %132 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %133 : Long(requires_grad=0, device=cpu) = onnx::Add(%131, %132)
#   %134 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %135 : Long(requires_grad=0, device=cpu) = onnx::Add(%129, %134)
#   %136 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %137 : Long(requires_grad=0, device=cpu) = onnx::Add(%135, %136)
#   %138 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%120)
#   %139 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%123)
#   %140 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%133)
#   %141 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%137)
#   %142 : Long(4, strides=[1], device=cpu) = onnx::Concat[axis=0](%138, %139, %140, %141)
#   %143 : Float(1, 12, 60, 100, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::ConstantOfShape[value={0}](%142) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4578:0
#   %144 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %145 : Long(requires_grad=0, device=cpu) = onnx::Sub(%133, %144)
#   %146 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %147 : Long(requires_grad=0, device=cpu) = onnx::Sub(%137, %146)
#   %148 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %149 : Long(requires_grad=0, device=cpu) = onnx::Sub(%126, %148)
#   %150 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %151 : Long(requires_grad=0, device=cpu) = onnx::Sub(%129, %150)
#   %155 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%149)
#   %157 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %158 : Float(1, 12, 56, 96, strides=[64512, 5376, 96, 1], requires_grad=0, device=cpu) = onnx::Slice(%117, %2921, %155, %2922, %157) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4602:0
#   %162 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%151)
#   %164 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %165 : Float(1, 12, 56, 96, strides=[64512, 5376, 96, 1], requires_grad=0, device=cpu) = onnx::Slice(%158, %2923, %162, %2924, %164) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4602:0
#   %169 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%145)
#   %171 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %172 : Float(1, 12, 56, 100, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::Slice(%143, %2925, %169, %2926, %171) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4602:0
#   %176 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%147)
#   %178 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %179 : Float(1, 12, 56, 96, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::Slice(%172, %2927, %176, %2928, %178) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4602:0
#   %180 : Long(4, strides=[1], device=cpu) = onnx::Shape(%179)
#   %181 : Float(1, 12, 56, 96, strides=[64512, 5376, 96, 1], requires_grad=0, device=cpu) = onnx::Expand(%165, %180) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4602:0
#   %182 : Long(4, strides=[1], device=cpu) = onnx::Shape(%143)
#   %183 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %184 : Long(device=cpu) = onnx::Gather[axis=0](%182, %183)
#   %185 : Long(device=cpu) = onnx::Cast[to=7](%184)
#   %186 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %187 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %188 : Long(1, device=cpu) = onnx::Range(%186, %185, %187)
#   %189 : Long(4, strides=[1], device=cpu) = onnx::Shape(%143)
#   %190 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %191 : Long(device=cpu) = onnx::Gather[axis=0](%189, %190)
#   %192 : Long(device=cpu) = onnx::Cast[to=7](%191)
#   %193 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %194 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %195 : Long(12, device=cpu) = onnx::Range(%193, %192, %194)
#   %196 : Long(4, strides=[1], device=cpu) = onnx::Shape(%143)
#   %197 : Long(device=cpu) = onnx::Constant[value={2}]()
#   %198 : Long(device=cpu) = onnx::Gather[axis=0](%196, %197)
#   %199 : Long(device=cpu) = onnx::Cast[to=7](%198)
#   %200 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %201 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %202 : Long(60, device=cpu) = onnx::Range(%200, %199, %201)
#   %205 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%145)
#   %207 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %208 : Long(56, device=cpu) = onnx::Slice(%202, %2929, %205, %2930, %207)
#   %209 : Long(4, strides=[1], device=cpu) = onnx::Shape(%143)
#   %210 : Long(device=cpu) = onnx::Constant[value={3}]()
#   %211 : Long(device=cpu) = onnx::Gather[axis=0](%209, %210)
#   %212 : Long(device=cpu) = onnx::Cast[to=7](%211)
#   %213 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %214 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %215 : Long(100, device=cpu) = onnx::Range(%213, %212, %214)
#   %218 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%147)
#   %220 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %221 : Long(96, device=cpu) = onnx::Slice(%215, %2931, %218, %2932, %220)
#   %222 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1  1 [ CPULongType{4} ]]()
#   %223 : Long(1, 1, 1, 1, strides=[1, 1, 1, 1], device=cpu) = onnx::Reshape(%188, %222)
#   %224 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %225 : Long(12, 1, 1, strides=[1, 1, 1], device=cpu) = onnx::Reshape(%195, %224)
#   %226 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %227 : Long(56, 1, strides=[1, 1], device=cpu) = onnx::Reshape(%208, %226)
#   %228 : Long(1, 12, 1, 1, strides=[12, 1, 1, 1], device=cpu) = onnx::Add(%223, %225)
#   %229 : Long(1, 12, 56, 1, strides=[672, 56, 1, 1], device=cpu) = onnx::Add(%228, %227)
#   %230 : Long(1, 12, 56, 96, strides=[64512, 5376, 96, 1], device=cpu) = onnx::Add(%229, %221)
#   %231 : Long(4, strides=[1], device=cpu) = onnx::Shape(%230)
#   %232 : Long(1, strides=[1], device=cpu) = onnx::Shape(%231)
#   %233 : Long(4, device=cpu) = onnx::ConstantOfShape[value={1}](%232)
#   %234 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %235 : Long(4, strides=[1], device=cpu) = onnx::Mul(%233, %234)
#   %236 : Bool(4, strides=[1], device=cpu) = onnx::Equal(%231, %235)
#   %237 : Long(4, strides=[1], device=cpu) = onnx::Where(%236, %233, %231)
#   %238 : Long(1, 12, 56, 96, device=cpu) = onnx::Expand(%223, %237)
#   %239 : Long(1, 12, 56, 96, 1, strides=[64512, 5376, 96, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%238)
#   %240 : Long(1, strides=[1], device=cpu) = onnx::Shape(%231)
#   %241 : Long(4, device=cpu) = onnx::ConstantOfShape[value={1}](%240)
#   %242 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %243 : Long(4, strides=[1], device=cpu) = onnx::Mul(%241, %242)
#   %244 : Bool(4, strides=[1], device=cpu) = onnx::Equal(%231, %243)
#   %245 : Long(4, strides=[1], device=cpu) = onnx::Where(%244, %241, %231)
#   %246 : Long(1, 12, 56, 96, device=cpu) = onnx::Expand(%225, %245)
#   %247 : Long(1, 12, 56, 96, 1, strides=[64512, 5376, 96, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%246)
#   %248 : Long(1, strides=[1], device=cpu) = onnx::Shape(%231)
#   %249 : Long(4, device=cpu) = onnx::ConstantOfShape[value={1}](%248)
#   %250 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %251 : Long(4, strides=[1], device=cpu) = onnx::Mul(%249, %250)
#   %252 : Bool(4, strides=[1], device=cpu) = onnx::Equal(%231, %251)
#   %253 : Long(4, strides=[1], device=cpu) = onnx::Where(%252, %249, %231)
#   %254 : Long(1, 12, 56, 96, device=cpu) = onnx::Expand(%227, %253)
#   %255 : Long(1, 12, 56, 96, 1, strides=[64512, 5376, 96, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%254)
#   %256 : Long(1, strides=[1], device=cpu) = onnx::Shape(%231)
#   %257 : Long(4, device=cpu) = onnx::ConstantOfShape[value={1}](%256)
#   %258 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %259 : Long(4, strides=[1], device=cpu) = onnx::Mul(%257, %258)
#   %260 : Bool(4, strides=[1], device=cpu) = onnx::Equal(%231, %259)
#   %261 : Long(4, strides=[1], device=cpu) = onnx::Where(%260, %257, %231)
#   %262 : Long(1, 12, 56, 96, device=cpu) = onnx::Expand(%221, %261)
#   %263 : Long(1, 12, 56, 96, 1, strides=[64512, 5376, 96, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%262)
#   %264 : Long(1, 12, 56, 96, 4, strides=[258048, 21504, 384, 4, 1], device=cpu) = onnx::Concat[axis=-1](%239, %247, %255, %263)
#   %265 : Long(4, strides=[1], device=cpu) = onnx::Shape(%143)
#   %266 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %267 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={4}]()
#   %268 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %269 : Long(0, strides=[1], device=cpu) = onnx::Slice(%265, %267, %268, %266)
#   %270 : Long(4, strides=[1], device=cpu) = onnx::Concat[axis=0](%231, %269)
#   %271 : Float(1, 12, 56, 96, device=cpu) = onnx::Reshape(%181, %270)
#   %272 : Float(1, 12, 60, 100, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%143, %264, %271) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4637:0
#   %273 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %274 : Long(requires_grad=0, device=cpu) = onnx::Sub(%133, %273)
#   %275 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %276 : Long(requires_grad=0, device=cpu) = onnx::Sub(%274, %275)
#   %277 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %278 : Long(requires_grad=0, device=cpu) = onnx::Sub(%133, %277)
#   %280 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%276)
#   %281 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%278)
#   %283 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %284 : Float(1, 12, 2, 100, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::Slice(%272, %280, %281, %2933, %283) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4637:0
#   %285 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %286 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %287 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %288 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %289 : Float(1, 12, 2, 100, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::Slice(%272, %286, %287, %285, %288) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4637:0
#   %290 : Long(4, strides=[1], device=cpu) = onnx::Shape(%289)
#   %291 : Float(1, 12, 2, 100, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::Expand(%284, %290) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4637:0
#   %292 : Long(4, strides=[1], device=cpu) = onnx::Shape(%272)
#   %293 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %294 : Long(device=cpu) = onnx::Gather[axis=0](%292, %293)
#   %295 : Long(device=cpu) = onnx::Cast[to=7](%294)
#   %296 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %297 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %298 : Long(1, device=cpu) = onnx::Range(%296, %295, %297)
#   %299 : Long(4, strides=[1], device=cpu) = onnx::Shape(%272)
#   %300 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %301 : Long(device=cpu) = onnx::Gather[axis=0](%299, %300)
#   %302 : Long(device=cpu) = onnx::Cast[to=7](%301)
#   %303 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %304 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %305 : Long(12, device=cpu) = onnx::Range(%303, %302, %304)
#   %306 : Long(4, strides=[1], device=cpu) = onnx::Shape(%272)
#   %307 : Long(device=cpu) = onnx::Constant[value={2}]()
#   %308 : Long(device=cpu) = onnx::Gather[axis=0](%306, %307)
#   %309 : Long(device=cpu) = onnx::Cast[to=7](%308)
#   %310 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %311 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %312 : Long(60, device=cpu) = onnx::Range(%310, %309, %311)
#   %313 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %314 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %315 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %316 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %317 : Long(2, strides=[1], device=cpu) = onnx::Slice(%312, %314, %315, %313, %316)
#   %318 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %319 : Long(1, 1, 1, strides=[1, 1, 1], device=cpu) = onnx::Reshape(%298, %318)
#   %320 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %321 : Long(12, 1, strides=[1, 1], device=cpu) = onnx::Reshape(%305, %320)
#   %322 : Long(1, 12, 1, strides=[12, 1, 1], device=cpu) = onnx::Add(%319, %321)
#   %323 : Long(1, 12, 2, strides=[24, 2, 1], device=cpu) = onnx::Add(%322, %317)
#   %324 : Long(3, strides=[1], device=cpu) = onnx::Shape(%323)
#   %325 : Long(1, strides=[1], device=cpu) = onnx::Shape(%324)
#   %326 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%325)
#   %327 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %328 : Long(3, strides=[1], device=cpu) = onnx::Mul(%326, %327)
#   %329 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%324, %328)
#   %330 : Long(3, strides=[1], device=cpu) = onnx::Where(%329, %326, %324)
#   %331 : Long(1, 12, 2, device=cpu) = onnx::Expand(%319, %330)
#   %332 : Long(1, 12, 2, 1, strides=[24, 2, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%331)
#   %333 : Long(1, strides=[1], device=cpu) = onnx::Shape(%324)
#   %334 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%333)
#   %335 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %336 : Long(3, strides=[1], device=cpu) = onnx::Mul(%334, %335)
#   %337 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%324, %336)
#   %338 : Long(3, strides=[1], device=cpu) = onnx::Where(%337, %334, %324)
#   %339 : Long(1, 12, 2, device=cpu) = onnx::Expand(%321, %338)
#   %340 : Long(1, 12, 2, 1, strides=[24, 2, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%339)
#   %341 : Long(1, strides=[1], device=cpu) = onnx::Shape(%324)
#   %342 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%341)
#   %343 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %344 : Long(3, strides=[1], device=cpu) = onnx::Mul(%342, %343)
#   %345 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%324, %344)
#   %346 : Long(3, strides=[1], device=cpu) = onnx::Where(%345, %342, %324)
#   %347 : Long(1, 12, 2, device=cpu) = onnx::Expand(%317, %346)
#   %348 : Long(1, 12, 2, 1, strides=[24, 2, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%347)
#   %349 : Long(1, 12, 2, 3, strides=[72, 6, 3, 1], device=cpu) = onnx::Concat[axis=-1](%332, %340, %348)
#   %350 : Long(4, strides=[1], device=cpu) = onnx::Shape(%272)
#   %351 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %352 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %353 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %354 : Long(1, strides=[1], device=cpu) = onnx::Slice(%350, %352, %353, %351)
#   %355 : Long(4, strides=[1], device=cpu) = onnx::Concat[axis=0](%324, %354)
#   %356 : Float(1, 12, 2, 100, device=cpu) = onnx::Reshape(%291, %355)
#   %357 : Float(1, 12, 60, 100, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%272, %349, %356) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4643:0
#   %358 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %359 : Long(requires_grad=0, device=cpu) = onnx::Sub(%133, %358)
#   %360 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %361 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %362 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={4}]()
#   %363 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %364 : Float(1, 12, 2, 100, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::Slice(%357, %361, %362, %360, %363) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4643:0
#   %366 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%359)
#   %367 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%133)
#   %369 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %370 : Float(1, 12, 2, 100, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::Slice(%357, %366, %367, %2934, %369) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4643:0
#   %371 : Long(4, strides=[1], device=cpu) = onnx::Shape(%370)
#   %372 : Float(1, 12, 2, 100, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::Expand(%364, %371) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4643:0
#   %373 : Long(4, strides=[1], device=cpu) = onnx::Shape(%357)
#   %374 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %375 : Long(device=cpu) = onnx::Gather[axis=0](%373, %374)
#   %376 : Long(device=cpu) = onnx::Cast[to=7](%375)
#   %377 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %378 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %379 : Long(1, device=cpu) = onnx::Range(%377, %376, %378)
#   %380 : Long(4, strides=[1], device=cpu) = onnx::Shape(%357)
#   %381 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %382 : Long(device=cpu) = onnx::Gather[axis=0](%380, %381)
#   %383 : Long(device=cpu) = onnx::Cast[to=7](%382)
#   %384 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %385 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %386 : Long(12, device=cpu) = onnx::Range(%384, %383, %385)
#   %387 : Long(4, strides=[1], device=cpu) = onnx::Shape(%357)
#   %388 : Long(device=cpu) = onnx::Constant[value={2}]()
#   %389 : Long(device=cpu) = onnx::Gather[axis=0](%387, %388)
#   %390 : Long(device=cpu) = onnx::Cast[to=7](%389)
#   %391 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %392 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %393 : Long(60, device=cpu) = onnx::Range(%391, %390, %392)
#   %395 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%359)
#   %396 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%133)
#   %398 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %399 : Long(2, device=cpu) = onnx::Slice(%393, %395, %396, %2935, %398)
#   %400 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %401 : Long(1, 1, 1, strides=[1, 1, 1], device=cpu) = onnx::Reshape(%379, %400)
#   %402 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %403 : Long(12, 1, strides=[1, 1], device=cpu) = onnx::Reshape(%386, %402)
#   %404 : Long(1, 12, 1, strides=[12, 1, 1], device=cpu) = onnx::Add(%401, %403)
#   %405 : Long(1, 12, 2, strides=[24, 2, 1], device=cpu) = onnx::Add(%404, %399)
#   %406 : Long(3, strides=[1], device=cpu) = onnx::Shape(%405)
#   %407 : Long(1, strides=[1], device=cpu) = onnx::Shape(%406)
#   %408 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%407)
#   %409 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %410 : Long(3, strides=[1], device=cpu) = onnx::Mul(%408, %409)
#   %411 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%406, %410)
#   %412 : Long(3, strides=[1], device=cpu) = onnx::Where(%411, %408, %406)
#   %413 : Long(1, 12, 2, device=cpu) = onnx::Expand(%401, %412)
#   %414 : Long(1, 12, 2, 1, strides=[24, 2, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%413)
#   %415 : Long(1, strides=[1], device=cpu) = onnx::Shape(%406)
#   %416 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%415)
#   %417 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %418 : Long(3, strides=[1], device=cpu) = onnx::Mul(%416, %417)
#   %419 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%406, %418)
#   %420 : Long(3, strides=[1], device=cpu) = onnx::Where(%419, %416, %406)
#   %421 : Long(1, 12, 2, device=cpu) = onnx::Expand(%403, %420)
#   %422 : Long(1, 12, 2, 1, strides=[24, 2, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%421)
#   %423 : Long(1, strides=[1], device=cpu) = onnx::Shape(%406)
#   %424 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%423)
#   %425 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %426 : Long(3, strides=[1], device=cpu) = onnx::Mul(%424, %425)
#   %427 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%406, %426)
#   %428 : Long(3, strides=[1], device=cpu) = onnx::Where(%427, %424, %406)
#   %429 : Long(1, 12, 2, device=cpu) = onnx::Expand(%399, %428)
#   %430 : Long(1, 12, 2, 1, strides=[24, 2, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%429)
#   %431 : Long(1, 12, 2, 3, strides=[72, 6, 3, 1], device=cpu) = onnx::Concat[axis=-1](%414, %422, %430)
#   %432 : Long(4, strides=[1], device=cpu) = onnx::Shape(%357)
#   %433 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %434 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %435 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %436 : Long(1, strides=[1], device=cpu) = onnx::Slice(%432, %434, %435, %433)
#   %437 : Long(4, strides=[1], device=cpu) = onnx::Concat[axis=0](%406, %436)
#   %438 : Float(1, 12, 2, 100, device=cpu) = onnx::Reshape(%372, %437)
#   %439 : Float(1, 12, 60, 100, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%357, %431, %438) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4652:0
#   %440 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %441 : Long(requires_grad=0, device=cpu) = onnx::Sub(%137, %440)
#   %442 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %443 : Long(requires_grad=0, device=cpu) = onnx::Sub(%441, %442)
#   %444 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %445 : Long(requires_grad=0, device=cpu) = onnx::Sub(%137, %444)
#   %447 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%443)
#   %448 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%445)
#   %450 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %451 : Float(1, 12, 60, 2, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::Slice(%439, %447, %448, %2936, %450) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4652:0
#   %452 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %453 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %454 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %455 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %456 : Float(1, 12, 60, 2, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::Slice(%439, %453, %454, %452, %455) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4652:0
#   %457 : Long(4, strides=[1], device=cpu) = onnx::Shape(%456)
#   %458 : Float(1, 12, 60, 2, strides=[72000, 6000, 100, 1], requires_grad=0, device=cpu) = onnx::Expand(%451, %457) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4652:0
#   %459 : Long(4, strides=[1], device=cpu) = onnx::Shape(%439)
#   %460 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %461 : Long(device=cpu) = onnx::Gather[axis=0](%459, %460)
#   %462 : Long(device=cpu) = onnx::Cast[to=7](%461)
#   %463 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %464 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %465 : Long(1, device=cpu) = onnx::Range(%463, %462, %464)
#   %466 : Long(4, strides=[1], device=cpu) = onnx::Shape(%439)
#   %467 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %468 : Long(device=cpu) = onnx::Gather[axis=0](%466, %467)
#   %469 : Long(device=cpu) = onnx::Cast[to=7](%468)
#   %470 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %471 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %472 : Long(12, device=cpu) = onnx::Range(%470, %469, %471)
#   %473 : Long(4, strides=[1], device=cpu) = onnx::Shape(%439)
#   %474 : Long(device=cpu) = onnx::Constant[value={2}]()
#   %475 : Long(device=cpu) = onnx::Gather[axis=0](%473, %474)
#   %476 : Long(device=cpu) = onnx::Cast[to=7](%475)
#   %477 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %478 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %479 : Long(60, device=cpu) = onnx::Range(%477, %476, %478)
#   %480 : Long(4, strides=[1], device=cpu) = onnx::Shape(%439)
#   %481 : Long(device=cpu) = onnx::Constant[value={3}]()
#   %482 : Long(device=cpu) = onnx::Gather[axis=0](%480, %481)
#   %483 : Long(device=cpu) = onnx::Cast[to=7](%482)
#   %484 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %485 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %486 : Long(100, device=cpu) = onnx::Range(%484, %483, %485)
#   %487 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %488 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %489 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %490 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %491 : Long(2, strides=[1], device=cpu) = onnx::Slice(%486, %488, %489, %487, %490)
#   %492 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1  1 [ CPULongType{4} ]]()
# ...
#   %2731 : Long(116, device=cpu) = onnx::Range(%2729, %2728, %2730)
#   %2733 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%2690)
#   %2734 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%2283)
#   %2736 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %2737 : Long(10, device=cpu) = onnx::Slice(%2731, %2733, %2734, %3118, %2736)
#   %2738 : Long(4, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1  1 [ CPULongType{4} ]]()
#   %2739 : Long(1, 1, 1, 1, strides=[1, 1, 1, 1], device=cpu) = onnx::Reshape(%2710, %2738)
#   %2740 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %2741 : Long(12, 1, 1, strides=[1, 1, 1], device=cpu) = onnx::Reshape(%2717, %2740)
#   %2742 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %2743 : Long(76, 1, strides=[1, 1], device=cpu) = onnx::Reshape(%2724, %2742)
#   %2744 : Long(1, 12, 1, 1, strides=[12, 1, 1, 1], device=cpu) = onnx::Add(%2739, %2741)
#   %2745 : Long(1, 12, 76, 1, strides=[912, 76, 1, 1], device=cpu) = onnx::Add(%2744, %2743)
#   %2746 : Long(1, 12, 76, 10, strides=[9120, 760, 10, 1], device=cpu) = onnx::Add(%2745, %2737)
#   %2747 : Long(4, strides=[1], device=cpu) = onnx::Shape(%2746)
#   %2748 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2747)
#   %2749 : Long(4, device=cpu) = onnx::ConstantOfShape[value={1}](%2748)
#   %2750 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2751 : Long(4, strides=[1], device=cpu) = onnx::Mul(%2749, %2750)
#   %2752 : Bool(4, strides=[1], device=cpu) = onnx::Equal(%2747, %2751)
#   %2753 : Long(4, strides=[1], device=cpu) = onnx::Where(%2752, %2749, %2747)
#   %2754 : Long(1, 12, 76, 10, device=cpu) = onnx::Expand(%2739, %2753)
#   %2755 : Long(1, 12, 76, 10, 1, strides=[9120, 760, 10, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%2754)
#   %2756 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2747)
#   %2757 : Long(4, device=cpu) = onnx::ConstantOfShape[value={1}](%2756)
#   %2758 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2759 : Long(4, strides=[1], device=cpu) = onnx::Mul(%2757, %2758)
#   %2760 : Bool(4, strides=[1], device=cpu) = onnx::Equal(%2747, %2759)
#   %2761 : Long(4, strides=[1], device=cpu) = onnx::Where(%2760, %2757, %2747)
#   %2762 : Long(1, 12, 76, 10, device=cpu) = onnx::Expand(%2741, %2761)
#   %2763 : Long(1, 12, 76, 10, 1, strides=[9120, 760, 10, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%2762)
#   %2764 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2747)
#   %2765 : Long(4, device=cpu) = onnx::ConstantOfShape[value={1}](%2764)
#   %2766 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2767 : Long(4, strides=[1], device=cpu) = onnx::Mul(%2765, %2766)
#   %2768 : Bool(4, strides=[1], device=cpu) = onnx::Equal(%2747, %2767)
#   %2769 : Long(4, strides=[1], device=cpu) = onnx::Where(%2768, %2765, %2747)
#   %2770 : Long(1, 12, 76, 10, device=cpu) = onnx::Expand(%2743, %2769)
#   %2771 : Long(1, 12, 76, 10, 1, strides=[9120, 760, 10, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%2770)
#   %2772 : Long(1, strides=[1], device=cpu) = onnx::Shape(%2747)
#   %2773 : Long(4, device=cpu) = onnx::ConstantOfShape[value={1}](%2772)
#   %2774 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %2775 : Long(4, strides=[1], device=cpu) = onnx::Mul(%2773, %2774)
#   %2776 : Bool(4, strides=[1], device=cpu) = onnx::Equal(%2747, %2775)
#   %2777 : Long(4, strides=[1], device=cpu) = onnx::Where(%2776, %2773, %2747)
#   %2778 : Long(1, 12, 76, 10, device=cpu) = onnx::Expand(%2737, %2777)
#   %2779 : Long(1, 12, 76, 10, 1, strides=[9120, 760, 10, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[-1]](%2778)
#   %2780 : Long(1, 12, 76, 10, 4, strides=[36480, 3040, 40, 4, 1], device=cpu) = onnx::Concat[axis=-1](%2755, %2763, %2771, %2779)
#   %2781 : Long(4, strides=[1], device=cpu) = onnx::Shape(%2688)
#   %2782 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %2783 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={4}]()
#   %2784 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %2785 : Long(0, strides=[1], device=cpu) = onnx::Slice(%2781, %2783, %2784, %2782)
#   %2786 : Long(4, strides=[1], device=cpu) = onnx::Concat[axis=0](%2747, %2785)
#   %2787 : Float(1, 12, 76, 10, device=cpu) = onnx::Reshape(%2703, %2786)
#   %2788 : Float(1, 12, 76, 116, strides=[105792, 8816, 116, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%2688, %2780, %2787) # c:\Users\chrys\AppData\Local\Programs\Python\Python37\lib\site-packages\torch\nn\functional.py:4658:0
#   %2789 : Float(12, 12, 21, 21, strides=[5292, 441, 21, 1], requires_grad=0, device=cpu) = onnx::Constant[value=<Tensor>]() # <ipython-input-28-1586e7562435>:79:0
#   %2790 : Float(1, 12, 56, 96, strides=[64512, 5376, 96, 1], requires_grad=0, device=cpu) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[21, 21], pads=[0, 0, 0, 0], strides=[1, 1]](%2788, %2789) # <ipython-input-28-1586e7562435>:79:0
#   %2791 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Squeeze[axes=[0]](%2790) # <ipython-input-28-1586e7562435>:79:0
#   %2792 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Add(%2262, %2791) # <ipython-input-28-1586e7562435>:81:0
#   %2793 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.05}]()
#   %2794 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Mul(%2792, %2793)
#   %2795 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Add(%InhibitoryCell.1, %2794) # <ipython-input-28-1586e7562435>:83:0
#   %InhibitoryCell : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Relu(%2795) # <ipython-input-19-026558775876>:16:0
#   %2797 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %2798 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Less(%ExcitatoryCell, %2797) # <ipython-input-19-026558775876>:4:0
#   %2799 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%2798) # <ipython-input-19-026558775876>:5:0
#   %2800 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%2799)
#   %2801 : Float(device=cpu) = onnx::Constant[value={0}]()
#   %2802 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Where(%2800, %2801, %ExcitatoryCell) # <ipython-input-19-026558775876>:5:0
#   %2803 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %2804 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Less(%2802, %2803)
#   %2805 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Not(%2804) # <ipython-input-19-026558775876>:7:0
#   %2806 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %2807 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Greater(%2802, %2806)
#   %2808 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Not(%2807) # <ipython-input-19-026558775876>:7:0
#   %2809 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%2805)
#   %2810 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%2808)
#   %2811 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::And(%2809, %2810)
#   %2812 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%2811) # <ipython-input-19-026558775876>:7:0
#   %2813 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%2812) # <ipython-input-19-026558775876>:8:0
#   %2814 : Long(3, *, device=cpu) = onnx::NonZero(%2813)
#   %2815 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%2814)
#   %2816 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::GatherND(%2802, %2815) # <ipython-input-19-026558775876>:8:0
#   %2817 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1}]()
#   %2818 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::Sub(%2816, %2817)
#   %2819 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%2813) # <ipython-input-19-026558775876>:8:0
#   %2820 : Long(3, strides=[1], device=cpu) = onnx::Shape(%2802)
#   %2821 : Bool(12, 56, 96, device=cpu) = onnx::Expand(%2819, %2820)
#   %2822 : Long(3, *, device=cpu) = onnx::NonZero(%2821)
#   %2823 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%2822)
#   %2824 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]()
#   %2825 : Float(*, device=cpu) = onnx::Reshape(%2818, %2824)
#   %2826 : Long(2, strides=[1], device=cpu) = onnx::Shape(%2823)
#   %2827 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %2828 : Long(device=cpu) = onnx::Gather[axis=0](%2826, %2827)
#   %2831 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%2828)
#   %2834 : Float(*, device=cpu) = onnx::Slice(%2825, %3119, %2831, %3120)
#   %2835 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%2802, %2823, %2834) # <ipython-input-19-026558775876>:8:0
#   %2836 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2}]()
#   %2837 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Greater(%2835, %2836) # <ipython-input-19-026558775876>:10:0
#   %2838 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%2837) # <ipython-input-19-026558775876>:11:0
#   %2839 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%2838)
#   %2840 : Float(device=cpu) = onnx::Constant[value={1}]()
#   %gExcitatoryCell : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Where(%2839, %2840, %2835) # <ipython-input-19-026558775876>:11:0
#   %2842 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %2843 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Less(%InhibitoryCell, %2842) # <ipython-input-19-026558775876>:18:0
#   %2844 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%2843) # <ipython-input-19-026558775876>:19:0
#   %2845 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%2844)
#   %2846 : Float(device=cpu) = onnx::Constant[value={0}]()
#   %2847 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Where(%2845, %2846, %InhibitoryCell) # <ipython-input-19-026558775876>:19:0
#   %2848 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0}]()
#   %2849 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Less(%2847, %2848)
#   %2850 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Not(%2849) # <ipython-input-19-026558775876>:21:0
#   %2851 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1.2}]()
#   %2852 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Greater(%2847, %2851)
#   %2853 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Not(%2852) # <ipython-input-19-026558775876>:21:0
#   %2854 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%2850)
#   %2855 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Cast[to=9](%2853)
#   %2856 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::And(%2854, %2855)
#   %2857 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%2856) # <ipython-input-19-026558775876>:21:0
#   %2858 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%2857) # <ipython-input-19-026558775876>:22:0
#   %2859 : Long(3, *, device=cpu) = onnx::NonZero(%2858)
#   %2860 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%2859)
#   %2861 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::GatherND(%2847, %2860) # <ipython-input-19-026558775876>:22:0
#   %2862 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.21}]()
#   %2863 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::Mul(%2861, %2862)
#   %2864 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%2858) # <ipython-input-19-026558775876>:22:0
#   %2865 : Long(3, strides=[1], device=cpu) = onnx::Shape(%2847)
#   %2866 : Bool(12, 56, 96, device=cpu) = onnx::Expand(%2864, %2865)
#   %2867 : Long(3, *, device=cpu) = onnx::NonZero(%2866)
#   %2868 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%2867)
#   %2869 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]()
#   %2870 : Float(*, device=cpu) = onnx::Reshape(%2863, %2869)
#   %2871 : Long(2, strides=[1], device=cpu) = onnx::Shape(%2868)
#   %2872 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %2873 : Long(device=cpu) = onnx::Gather[axis=0](%2871, %2872)
#   %2876 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%2873)
#   %2879 : Float(*, device=cpu) = onnx::Slice(%2870, %3121, %2876, %3122)
#   %2880 : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%2847, %2868, %2879) # <ipython-input-19-026558775876>:22:0
#   %2881 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1.2}]()
#   %2882 : Bool(12, 56, 96, strides=[5376, 96, 1], device=cpu) = onnx::Less(%2880, %2881)
#   %2883 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Not(%2882) # <ipython-input-19-026558775876>:24:0
#   %2884 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%2883) # <ipython-input-19-026558775876>:25:0
#   %2885 : Long(3, *, device=cpu) = onnx::NonZero(%2884)
#   %2886 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%2885)
#   %2887 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::GatherND(%2880, %2886) # <ipython-input-19-026558775876>:25:0
#   %2888 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={1.2}]()
#   %2889 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::Sub(%2887, %2888)
#   %2890 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={2.5}]()
#   %2891 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::Mul(%2889, %2890)
#   %2892 : Float(requires_grad=0, device=cpu) = onnx::Constant[value={0.252}]()
#   %2893 : Float(*, strides=[1], requires_grad=0, device=cpu) = onnx::Add(%2891, %2892)
#   %2894 : Bool(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::Cast[to=9](%2884) # <ipython-input-19-026558775876>:25:0
#   %2895 : Long(3, strides=[1], device=cpu) = onnx::Shape(%2880)
#   %2896 : Bool(12, 56, 96, device=cpu) = onnx::Expand(%2894, %2895)
#   %2897 : Long(3, *, device=cpu) = onnx::NonZero(%2896)
#   %2898 : Long(*, 3, device=cpu) = onnx::Transpose[perm=[1, 0]](%2897)
#   %2899 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]()
#   %2900 : Float(*, device=cpu) = onnx::Reshape(%2893, %2899)
#   %2901 : Long(2, strides=[1], device=cpu) = onnx::Shape(%2898)
#   %2902 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %2903 : Long(device=cpu) = onnx::Gather[axis=0](%2901, %2902)
#   %2906 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%2903)
#   %2909 : Float(*, device=cpu) = onnx::Slice(%2900, %3123, %2906, %3124)
#   %gInhibitoryCell : Float(12, 56, 96, strides=[5376, 96, 1], requires_grad=0, device=cpu) = onnx::ScatterND(%2880, %2898, %2909) # <ipython-input-19-026558775876>:25:0
#   %avgSp : Float(requires_grad=0, device=cpu) = onnx::ReduceMean[keepdims=0](%ExcitatoryCell) # <ipython-input-28-1586e7562435>:89:0
#   %avgSm : Float(requires_grad=0, device=cpu) = onnx::ReduceMean[keepdims=0](%InhibitoryCell) # <ipython-input-28-1586e7562435>:89:0
#   %avgOutSp : Float(requires_grad=0, device=cpu) = onnx::ReduceMean[keepdims=0](%gExcitatoryCell) # <ipython-input-28-1586e7562435>:89:0
#   %avgOutSm : Float(requires_grad=0, device=cpu) = onnx::ReduceMean[keepdims=0](%gInhibitoryCell) # <ipython-input-28-1586e7562435>:89:0
#   return (%ExcitatoryCell, %InhibitoryCell, %gExcitatoryCell, %gInhibitoryCell, %avgSp, %avgSm, %avgOutSp, %avgOutSm)
